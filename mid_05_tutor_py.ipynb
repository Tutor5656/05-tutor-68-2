# %% [markdown]
# <a href="https://colab.research.google.com/github/Tutor5656/05-tutor-68-2/blob/main/mid_05_tutor_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mass = float(input("Please enter your mass :"))
velocity = float(input("Please enter your velocity :"))

KE = 0.5*mass*velocity**2
print("your KE is",KE)
# Out:
# Please enter your mass 56
# Please enter yourvelocity 56
# your KE is 87808.0
